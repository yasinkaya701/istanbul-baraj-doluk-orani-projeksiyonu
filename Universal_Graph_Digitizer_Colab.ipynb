# %% [markdown]
# # 🌍 Universal Graph Digitizer - Google Colab Edition
# This notebook allows you to process historical graph paper images (Temperature, Humidity, Pressure, Precip) in the cloud.
#
# ### 🚀 Setup Instructions
# 1. **Mount Google Drive**: Upload your image folders to Google Drive.
# 2. **Install Dependencies**: Run the first cell to install OpenCV and other tools.
# 3. **Set Paths**: Point the `ROOT_PATH` to your Drive folder.
# 4. **Run**: Process all images into Parquet/CSV formats.

# %%
#!pip install opencv-python-headless pandas numpy pillow scipy tqdm pyarrow
import os
import cv2
import pandas as pd
import numpy as np
from pathlib import Path
from google.colab import drive

# Mount Google Drive if using Colab
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# %%
# --- CONFIGURATION ---
ROOT_PATH = "/content/drive/MyDrive/Meteoroloji_Arsiv" # Image folder on Drive
OUTPUT_PATH = "/content/output_lake"
WORKERS = 4 # Colab usually has 2-4 cores depending on tier

os.makedirs(OUTPUT_PATH, exist_ok=True)

# %% [markdown]
# ### Digitization Logic (Core Engine)

# %%
# Paste the contents of export_universal_ai_graph.py here or import if paths are set
def process_everything():
    print("Starting batch digitization...")
    # Call the batch function implemented in the script
    pass

# process_everything()
